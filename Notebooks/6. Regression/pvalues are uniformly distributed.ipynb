# %% [markdown]
# # estimated model is: y = a0 + a1*x + e
#
# # x and y are independent, so null hypothesis is true

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

import numpy as np

# Artificial data:
num_obs = 100

x = np.random.normal(loc=0.0, scale=1.0, size=num_obs)
X = sm.add_constant(x)

y_true = np.random.normal(loc=0.0, scale=1.0, size=num_obs)
e = np.random.normal(size=num_obs)
y = y_true + e

# Fit and summary:
model = sm.OLS(y, X)
results = model.fit()

print(results.summary())

fig, ax = plt.subplots()
ax.plot(x, y, 'b.', label="data")
ax.plot(x, results.fittedvalues, 'r-', label="OLS")

plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6091
# Date:                Sat, 28 Apr 2018   Prob (F-statistic):              0.437
# Time:                        14:49:42   Log-Likelihood:                -180.92
# No. Observations:                 100   AIC:                             365.8
# Df Residuals:                      98   BIC:                             371.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0652      0.150     -0.436      0.664      -0.362       0.232
# x1             0.1045      0.134      0.780      0.437      -0.161       0.370
# ==============================================================================
# Omnibus:                        2.716   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.257   Jarque-Bera (JB):                2.132
# Skew:                          -0.238   Prob(JB):                        0.344
# Kurtosis:                       3.535   Cond. No.                         1.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import numpy as np
import statsmodels.api as sm

np.random.seed(9876789)

num_obs = 100
N = 10000

output = []
for i in range(N):
    x = np.random.normal(loc=0.0, scale=1.0, size=num_obs)
    X = sm.add_constant(x)

    y_true = np.random.normal(loc=0.0, scale=1.0, size=num_obs)
    e = np.random.normal(size=num_obs)
    y = y_true + e

    model = sm.OLS(y, X)
    results = model.fit()

    output.append(results.pvalues[1])

# %%
import matplotlib.pyplot as plt
import scipy.stats

fig, ax = plt.subplots(figsize=(20,6))

# the histogram of the data
plt.subplot(1, 2, 1)
n, bins, _ = plt.hist(output, bins=np.linspace(0,1,11), density=True, facecolor='green', alpha=0.5)

# probability plot (pp-plot) against uniform distribution
plt.subplot(1, 2, 2)
scipy.stats.probplot(output, dist="uniform", plot=plt)

plt.show()

# Null hypothesis is that output distr. is uniform
scipy.stats.kstest(output, 'uniform')
# Out:
# KstestResult(statistic=0.0069159081046553661, pvalue=0.72518493836969244)
